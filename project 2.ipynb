# %%
import pandas as pd

# %%
data_set=pd.read_excel('C:\\Users\\USER\\Downloads\\bike sales data.xlsx')

data_set
# Out:
#     Sales_Order #       Date   Day     Month  Year  Customer_Age  \
# 0          261695 2021-12-01   1.0  December  2021            39
# 1          261695 2021-12-01   1.0  December  2021            44
# 2          261697 2021-12-02   2.0  December  2021            37
# 3          261698 2021-12-02   2.0  December  2021            31
# 4          261699 2021-12-03   3.0  December  2021            37
# ..            ...        ...   ...       ...   ...           ...
# 84         261778 2021-12-22  22.0  December  2021            41
# 85         261779 2021-12-23  23.0  December  2021            30
# 86         261780 2021-12-23  23.0  December  2021            31
# 87         261781 2021-12-23  23.0  December  2021            35
# 88         261782 2021-12-24  24.0  December  2021            38
#
#                Age_Group Customer_Gender         Country             State  \
# 0         Adults (35-64)               F   United States        California
# ...

# %%
missing_value=data_set.isnull().sum()
print("Missing values:\n", missing_value)
# Out:
# Missing values:
#  Sales_Order #          0
# Date                   0
# Day                    1
# Month                  0
# Year                   0
# Customer_Age           0
# Age_Group              1
# Customer_Gender        0
# Country                0
# State                  0
# Product_Category       0
# Sub_Category           0
# Product_Description    1
# Order_Quantity         1
#  Unit_Cost             0
#  Unit_Price            0
#  Profit                0
#  Cost                  0
# Revenue                0
# dtype: int64

# %%
data_set.dropna(inplace=True)
data_set
# Out:
#     Sales_Order #       Date   Day     Month  Year  Customer_Age  \
# 0          261695 2021-12-01   1.0  December  2021            39
# 1          261695 2021-12-01   1.0  December  2021            44
# 2          261697 2021-12-02   2.0  December  2021            37
# 3          261698 2021-12-02   2.0  December  2021            31
# 4          261699 2021-12-03   3.0  December  2021            37
# ..            ...        ...   ...       ...   ...           ...
# 84         261778 2021-12-22  22.0  December  2021            41
# 85         261779 2021-12-23  23.0  December  2021            30
# 86         261780 2021-12-23  23.0  December  2021            31
# 87         261781 2021-12-23  23.0  December  2021            35
# 88         261782 2021-12-24  24.0  December  2021            38
#
#                Age_Group Customer_Gender         Country             State  \
# 0         Adults (35-64)               F   United States        California
# ...

# %%
data_set.dropna(axis=1, inplace=True)
data_set
# Out:
#     Sales_Order #       Date   Day     Month  Year  Customer_Age  \
# 0          261695 2021-12-01   1.0  December  2021            39
# 1          261695 2021-12-01   1.0  December  2021            44
# 2          261697 2021-12-02   2.0  December  2021            37
# 3          261698 2021-12-02   2.0  December  2021            31
# 4          261699 2021-12-03   3.0  December  2021            37
# ..            ...        ...   ...       ...   ...           ...
# 84         261778 2021-12-22  22.0  December  2021            41
# 85         261779 2021-12-23  23.0  December  2021            30
# 86         261780 2021-12-23  23.0  December  2021            31
# 87         261781 2021-12-23  23.0  December  2021            35
# 88         261782 2021-12-24  24.0  December  2021            38
#
#                Age_Group Customer_Gender         Country             State  \
# 0         Adults (35-64)               F   United States        California
# ...

# %%
data_set.loc[3]
# Out:
# Sales_Order #                             261698
# Date                         2021-12-02 00:00:00
# Day                                          2.0
# Month                                   December
# Year                                        2021
# Customer_Age                                  31
# Age_Group                   Young Adults (25-34)
# Customer_Gender                                F
# Country                                Australia
# State                            New South Wales
# Product_Category                           Bikes
# Sub_Category                      Mountain Bikes
# Product_Description    Mountain-400-W Silver, 42
# Order_Quantity                               1.0
#  Unit_Cost                                   420
#  Unit_Price                                  769
#  Profit                                      349
#  Cost                                        420
# Revenue                                      769
# Name: 3, dtype: object

# %%
data_set['Date'] = pd.to_datetime(data_set['Date'])

print("updated DataFrame:")
data_set
# Out:
# updated DataFrame:
#     Sales_Order #       Date   Day     Month  Year  Customer_Age  \
# 0          261695 2021-12-01   1.0  December  2021            39
# 1          261695 2021-12-01   1.0  December  2021            44
# 2          261697 2021-12-02   2.0  December  2021            37
# 3          261698 2021-12-02   2.0  December  2021            31
# 4          261699 2021-12-03   3.0  December  2021            37
# ..            ...        ...   ...       ...   ...           ...
# 84         261778 2021-12-22  22.0  December  2021            41
# 85         261779 2021-12-23  23.0  December  2021            30
# 86         261780 2021-12-23  23.0  December  2021            31
# 87         261781 2021-12-23  23.0  December  2021            35
# 88         261782 2021-12-24  24.0  December  2021            38
#
#                Age_Group Customer_Gender         Country             State  \
# 0         Adults (35-64)               F   United States        California
# ...

# %%
data_set[4:10]
# Out:
#    Sales_Order #       Date  Day     Month  Year  Customer_Age  \
# 4         261699 2021-12-03  3.0  December  2021            37
# 5         261700 2021-12-03  3.0  December  2021            24
# 6         261701 2021-12-03  3.0  December  2021            37
# 7         261701 2021-12-03  3.0  December  2021            37
# 8         261702 2021-12-04  4.0  December  2021            31
# 9         261703 2021-12-05  5.0  December  2021            39
#
#               Age_Group Customer_Gender         Country            State  \
# 4        Adults (35-64)               F  United  States       California
# 5           Youth (<25)               F  United Kingdom          England
# 6        Adults (35-64)               M  United States        Washington
# 7        Adults (35-64)               M   United States       Washington
# 8  Young Adults (25-34)               F       Australia  New South Wales
# 9        Adults (35-64)               F   United States       California
#
# ...

# %%
data_set["Sub_Category"]
# Out:
# 0     Mountain Bikes
# 1     Mountain Bikes
# 2     Mountain Bikes
# 3     Mountain Bikes
# 4     Mountain Bikes
#            ...
# 84    Mountain Bikes
# 85    Mountain Bikes
# 86    Mountain Bikes
# 87    Mountain Bikes
# 88    Mountain Bikes
# Name: Sub_Category, Length: 85, dtype: object

# %%
data_set.rename(columns={"Product_Category":"product"})
# Out:
#     Sales_Order #       Date   Day     Month  Year  Customer_Age  \
# 0          261695 2021-12-01   1.0  December  2021            39
# 1          261695 2021-12-01   1.0  December  2021            44
# 2          261697 2021-12-02   2.0  December  2021            37
# 3          261698 2021-12-02   2.0  December  2021            31
# 4          261699 2021-12-03   3.0  December  2021            37
# ..            ...        ...   ...       ...   ...           ...
# 84         261778 2021-12-22  22.0  December  2021            41
# 85         261779 2021-12-23  23.0  December  2021            30
# 86         261780 2021-12-23  23.0  December  2021            31
# 87         261781 2021-12-23  23.0  December  2021            35
# 88         261782 2021-12-24  24.0  December  2021            38
#
#                Age_Group Customer_Gender         Country             State  \
# 0         Adults (35-64)               F   United States        California
# ...

# %%
data_set.iloc[[9,4],1]
# Out:
# 9   2021-12-05
# 4   2021-12-03
# Name: Date, dtype: datetime64[ns]

# %%
duplicates_mask = data_set.duplicated()
print(duplicates_mask)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 84    False
# 85    False
# 86    False
# 87    False
# 88    False
# Length: 85, dtype: bool

# %%
data_set.drop_duplicates(inplace=True)
data_set
# Out:
#     Sales_Order #       Date   Day     Month  Year  Customer_Age  \
# 0          261695 2021-12-01   1.0  December  2021            39
# 1          261695 2021-12-01   1.0  December  2021            44
# 2          261697 2021-12-02   2.0  December  2021            37
# 3          261698 2021-12-02   2.0  December  2021            31
# 4          261699 2021-12-03   3.0  December  2021            37
# ..            ...        ...   ...       ...   ...           ...
# 84         261778 2021-12-22  22.0  December  2021            41
# 85         261779 2021-12-23  23.0  December  2021            30
# 86         261780 2021-12-23  23.0  December  2021            31
# 87         261781 2021-12-23  23.0  December  2021            35
# 88         261782 2021-12-24  24.0  December  2021            38
#
#                Age_Group Customer_Gender         Country             State  \
# 0         Adults (35-64)               F   United States        California
# ...

# %%
data_set['Product_Description'] = data_set['Product_Description'].str.title()

print("\nDataFrame after cleaning text data:")
print(data_set['Product_Description'])
# Out:
# DataFrame after cleaning text data:
# 0        Mountain-200 Black, 46
# 1       Mountain-200 Silver, 42
# 2     Mountain-400-W Silver, 46
# 3     Mountain-400-W Silver, 42
# 4        Mountain-200 Black, 46
#                 ...
# 84      Mountain-200 Silver, 38
# 85      Mountain-200 Silver, 42
# 86       Mountain-200 Black, 42
# 87       Mountain-500 Black, 42
# 88       Mountain-200 Black, 42
# Name: Product_Description, Length: 85, dtype: object

# %%
indices_to_change = [0,2,8,18,12,20,23,25,26,32,35,37,39,43,46,49,50,51,60,88]
new_values = ['Regular Bike', 'Sports Bike','Electric Bike','Sports Bike','Electric Bike','Sports Bike','Regular Bike','Regular Bike','Sports Bike','Sports Bike','Sports Bike','Sports Bike','Sports Bike','Sports Bike','Regular Bike','Regular Bike','Regular Bike','Regular Bike','Electric Bike','Electric Bike']
data_set.loc[indices_to_change, 'Sub_Category'] = new_values
data_set['Sub_Category']
# Out:
# 0       Regular Bike
# 1     Mountain Bikes
# 2        Sports Bike
# 3     Mountain Bikes
# 4     Mountain Bikes
#            ...
# 84    Mountain Bikes
# 85    Mountain Bikes
# 86    Mountain Bikes
# 87    Mountain Bikes
# 88     Electric Bike
# Name: Sub_Category, Length: 85, dtype: object

# %%
data_set.drop(columns=['Product_Category','Date'], inplace=True)
data_set
# Out:
#     Sales_Order #   Day     Month  Year  Customer_Age             Age_Group  \
# 0          261695   1.0  December  2021            39        Adults (35-64)
# 1          261695   1.0  December  2021            44        Adults (35-64)
# 2          261697   2.0  December  2021            37        Adults (35-64)
# 3          261698   2.0  December  2021            31  Young Adults (25-34)
# 4          261699   3.0  December  2021            37        Adults (35-64)
# ..            ...   ...       ...   ...           ...                   ...
# 84         261778  22.0  December  2021            41        Adults (35-64)
# 85         261779  23.0  December  2021            30  Young Adults (25-34)
# 86         261780  23.0  December  2021            31  Young Adults (25-34)
# 87         261781  23.0  December  2021            35        Adults (35-64)
# 88         261782  24.0  December  2021            38        Adults (35-64)
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.displot(data=data_set, x=" Profit ",col="Country", kde=False)
plt.show
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.lineplot(data=data_set, x="Sub_Category", y="Customer_Age",hue="Country")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.lineplot(data=data_set, x="Sub_Category", y="Customer_Age",hue="Customer_Gender")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(data=data_set, x="Sub_Category", y="Customer_Age",hue="Customer_Gender")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(data=data_set, x="Sub_Category", y="Revenue",hue="Country")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
mean_values = data_set[Profit].mean()
mode_values = data_set[Order_Quantity].mode().iloc[0]  # Mode may have multiple values, so we take the first row
median_values = data_set[Revenue].median()

# Print the calculated statistics
print("Mean Values:")
print(mean_values)
print("\nMode Values:")
print(mode_values)
print("\nMedian Values:")
print(median_values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 mean_values = data_set[Profit].mean()
#       2 mode_values = data_set[Order_Quantity].mode().iloc[0]  # Mode may have multiple values, so we take the first row
#       3 median_values = data_set[Revenue].median()
#
# NameError: name 'Profit' is not defined
